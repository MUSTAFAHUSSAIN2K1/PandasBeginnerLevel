# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
content=pd.read_csv('/content/data.csv')

# %%
content
# Out:
#    year  revenue  cost
# 0  2010    100.0    30
# 1  2011    120.0   105
# 2  2012    130.0   207
# 3  2013    233.0   211
# 4  2014      NaN   152
# 5  2015    179.0   144
# 6  2016    300.0   246
# 7  2017    300.0   268

# %% [markdown]
# TO RENAME COLUMN NAME WE MUST DO
#
# content.rename(columns={"yeer":"Year"},inplace=True)

# %%
content['revenue'].fillna(value=content['revenue'].mean(),inplace=True)

# %%
content
# Out:
#    year     revenue  cost
# 0  2010  100.000000    30
# 1  2011  120.000000   105
# 2  2012  130.000000   207
# 3  2013  233.000000   211
# 4  2014  194.571429   152
# 5  2015  179.000000   144
# 6  2016  300.000000   246
# 7  2017  300.000000   268

# %% [markdown]
# TO ADD NEW COLUMN WE CAN DO THE FOLLOWING WORK

# %%
content['profit']=content['revenue']- content['cost']

# %%
content
# Out:
#    year     revenue  cost     profit
# 0  2010  100.000000    30  70.000000
# 1  2011  120.000000   105  15.000000
# 2  2012  130.000000   207 -77.000000
# 3  2013  233.000000   211  22.000000
# 4  2014  194.571429   152  42.571429
# 5  2015  179.000000   144  35.000000
# 6  2016  300.000000   246  54.000000
# 7  2017  300.000000   268  32.000000

# %%
plt.plot(content['year'],content['profit'])
plt.xlabel('year')
plt.ylabel('profit')
plt.title('CNQ')
# Out:
# Text(0.5, 1.0, 'CNQ')
